# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/preprocessed.zip"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-062.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-063.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-064.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-065.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-066.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-067.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-068.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-069.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-070.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-071.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-072.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-073.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-074.png
#  extracting: preprocessed/124/cl-02/162/124-cl-02-162-075.png
# ...

# %%
# !git clone https://github.com/an2101/GaitSet.git
# Out:
# Cloning into 'GaitSet'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 40 (delta 0), reused 5 (delta 0), pack-reused 33 (from 1)
# Receiving objects: 100% (40/40), 81.72 MiB | 11.38 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %% [markdown]
# Chỉnh sửa trong file Gaitset.py: dùng median/ dùng min/ bỏ nhánh gl

# %%
# !python /content/GaitSet/train.py
# Out:
# Initialzing...
# Initializing data source...
# Loading training data...
# Data initialization complete.
# Initializing model...
# Model initialization complete.
# Training START
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# iter 100:, hard_loss_metric=0.44600213, full_loss_metric=0.19383439, full_loss_num=187775.00000000, mean_dist=0.20469263, lr=0.000100, hard or full='full'
# iter 200:, hard_loss_metric=0.52850169, full_loss_metric=0.18982668, full_loss_num=140363.42187500, mean_dist=0.38717663, lr=0.000100, hard or full='full'
# ...

# %%
# !python /content/GaitSet/test.py --iter=1000
# Out:
# Initialzing...
# Initializing data source...
# Data initialization complete.
# Initializing model...
# Model initialization complete.
# Loading the model of iteration 1000...
# Transforming...
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Evaluating...
# Evaluation complete. Cost: 0:01:41.476511
# ===Rank-1 (Include identical-view cases)===
# NM: 75.529,	BG: 58.676,	CL: 38.587
# ===Rank-1 (Exclude identical-view cases)===
# NM: 73.155,	BG: 56.201,	CL: 36.882
# ===Rank-1 of each angle (Exclude identical-view cases)===
# ...
